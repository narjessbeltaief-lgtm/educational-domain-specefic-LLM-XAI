# %% [markdown]
# # 01 - Exploration
#
# Scratchpad for exploring the educational domain corpus, testing base LLM prompts for question generation and grading, before formalizing logic into `src/`.

# %%
import sys
sys.path.append('..')
from src.utils.config_loader import load_config

config = load_config('../config/config.yaml')
config
